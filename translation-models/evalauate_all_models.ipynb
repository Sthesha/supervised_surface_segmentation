# %%
import torch
from seq2seq_train import Seq2SeqTrainer
import json
import pandas as pd
from datetime import datetime
import os
from torchmetrics.text import SacreBLEUScore
from nltk.translate.bleu_score import corpus_bleu
import sacrebleu
import pandas as pd
# Out:
# 2025-03-24 22:37:16.883452: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-24 22:37:17.883823: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def save_model_comparison(config_paths):
    # Initialize lists to store results
    results = []
    
    for config_path in config_paths:
        print(f"Attempting to load from: {config_path}")
        
        with open(config_path, "r") as f:
            loaded_config = json.load(f)
        
        # Initialize trainer with new dataset size but keeping optimized parameters
        trainer = Seq2SeqTrainer(loaded_config)
        trainer.load_pretrained_model()

#         data = pd.read_csv("data/flores_en_zu_segmented.csv")
        
        # Get predictions and compute metrics
        predicted, targeted, sources = trainer.get_predictions_from_file()
        
        
        bleu_scores = trainer.eval_bleu_segment(predicted, targeted)
        chrf_score = trainer.eval_chrF_segment(predicted, targeted)
        sacre_bleu = trainer.eval_sacrebleu_segment(predicted, targeted)

        # Save individual model results
        trainer.save_evaluation_results(loaded_config["file_path"], bleu_scores, chrf_score, sacre_bleu)
        
        # Collect results for comparison
        result = {
            'model_name': loaded_config.get('model_name', loaded_config["file_path"].split("/")[-1]),
            'bleu_score': bleu_scores['simple'],
            'chrf': chrf_score,
            'timestamp': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        }
        results.append(result)
        
        print(f"Model: {result['model_name']}")
        print(f"BLEU={bleu_scores['simple']:.4f}")
        print(f"CHRF: {chrf_score:.4f}")
        
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
    
    # Create DataFrame and save to CSV
    df = pd.DataFrame(results)
    comparison_file = "model_comparison_results_zu_en_flores_testing_set.csv"
    
    # If file exists, append without headers
    if os.path.exists(comparison_file):
        df.to_csv(comparison_file, mode='a', header=False, index=False)
    else:
        df.to_csv(comparison_file, index=False)
    
    print(f"\nComparison results saved to: {comparison_file}")
    
    # Create a formatted markdown table for easy viewing
    markdown_table = "# Model Comparison Results\n\n"
    markdown_table += df.to_markdown(index=False)
    
    with open("model_comparison_results_zu_en_flores_testing_set.md", "w") as f:
        f.write(markdown_table)
    
    return df

# %%
if __name__ == "__main__":
    config_paths = [
        "zulu_english_models/zulu_english_none/model_config.json",
        "zulu_english_models/zulu_english_seg_one/model_config.json",
        "zulu_english_models/zulu_english_seg_two/model_config.json",
        "zulu_english_models/zulu_english_seg_three/model_config.json"
    ]
    
    comparison_df = save_model_comparison(config_paths)
    
    print("\nComparison Summary:")
    print(comparison_df)
# Out:
# Attempting to load from: zulu_english_models/zulu_english_none/model_config.json
# Using device: cuda
# Device name: NVIDIA RTX A6000
# Device memory: 47.535888671875 GB
# Original shape: (100000, 5)
# Final shape: (100000, 5)
# The config file has been saved on zulu_english_models/zulu_english_none
# the dataset length: 100000
# Tokenizer path: zulu_english_models/zulu_english_none/tokenizers/tokenizers_isizulu.json
# Loading existing tokenizer from zulu_english_models/zulu_english_none/tokenizers/tokenizers_isizulu.json
# Tokenizer path: zulu_english_models/zulu_english_none/tokenizers/tokenizers_english.json
# Loading existing tokenizer from zulu_english_models/zulu_english_none/tokenizers/tokenizers_english.json
# Max length of source sentence: 53
# Max length of target sentence: 77
# Loaded best model from epoch 21
# Model configuration:
# - d_model: 1024
# - num_layers: 3
# - num_heads: 8
# - d_ff: 1024
# - dropout: 0.2112720416358559
# - label_smoothing: 0.04818508143643119
# - max_grad_norm: 1.8325823336861036
# - lr: 5.176333543919269e-05
# Reading predictions from: zulu_english_models/zulu_english_none/external_predictions/test_predictions_20250113_034031.csv
# Successfully loaded 1012 predictions
#
# Example predictions:
#
# Example 1:
# Source: manje sinamagundane anezinyanga ezingu angenawo ushukela ayenoshukela wanezela
#
# Target: we now have monthold mice that are nondiabetic that used to be diabetic he added
# Predicted: now i have a bit of sugar baby twitter he added
#
# Example 2:
# Source: udkt ehud ur usolwazi wezokwelapha enyuvesi yasedalhousie ehalifax enova scotia kanye nosihlalo womnyango wezokwelapha nowesayensi wecanadian diabetes association uxwayise ngokuthi ucwaningo lusanda kuqala
#
# Target: dr ehud ur professor of medicine at dalhousie university in halifax nova scotia and chair of the clinical and scientific division of the canadian diabetes association cautioned that the research is still in its early days
# Predicted: dr r has also medical insurance university for the university of and medical care for medical medical and association that the association described as the first research first
#
# Example 3:
# Source: njengezinye izazi unokungabaza ukuthi isifo sikashukela singalashwa ephawula ukuthi lokhu okutholakele akubathinti asebevele benesifo sikashukela sohlobo loku
#
# Target: like some other experts he is skeptical about whether diabetes can be cured noting that these findings have no relevance to people who already have type  diabetes
# Predicted: as other scholars have believed that diabetes would be considered that this turned into the far far from the most diabetes type of this type
# Original pairs: 1012
# Valid pairs after filtering: 1012
# Filtered out 0 pairs
# Original pairs: 1012
# Valid pairs after filtering: 1012
# Filtered out 0 pairs
# Original pairs: 1012
# Valid pairs after filtering: 1012
# Filtered out 0 pairs
# The evaluation results were successfully saved to:
# - Text format: zulu_english_models/zulu_english_none/evaluation_results.txt
# Model: zulu_english_none
# BLEU=0.0762
# CHRF: 0.3289
# Attempting to load from: zulu_english_models/zulu_english_seg_one/model_config.json
# Using device: cuda
# Device name: NVIDIA RTX A6000
# Device memory: 47.535888671875 GB
# Original shape: (100000, 5)
# Final shape: (100000, 5)
# The config file has been saved on zulu_english_models/zulu_english_seg_one
# the dataset length: 100000
# Tokenizer path: zulu_english_models/zulu_english_seg_one/tokenizers/tokenizers_segmenter_one.json
# Loading existing tokenizer from zulu_english_models/zulu_english_seg_one/tokenizers/tokenizers_segmenter_one.json
# Vocabulary finalized for inference
# Tokenizer path: zulu_english_models/zulu_english_seg_one/tokenizers/tokenizers_english.json
# Loading existing tokenizer from zulu_english_models/zulu_english_seg_one/tokenizers/tokenizers_english.json
# Max length of source sentence: 301
# Max length of target sentence: 77
# Loaded best model from epoch 13
# Model configuration:
# - d_model: 512
# - num_layers: 3
# - num_heads: 4
# - d_ff: 2048
# - dropout: 0.1951270854322797
# - label_smoothing: 0.04332237263956871
# - max_grad_norm: 1.1460101261444786
# - lr: 0.0004551438410636057
# Reading predictions from: zulu_english_models/zulu_english_seg_one/external_predictions/test_predictions_20250113_021451.csv
# Successfully loaded 1012 predictions
#
# Example predictions:
#
# Example 1:
# Source: ma-nje si-n-a-ma-gundane a-n-e-zinyanga e-zin-gu a-nge-na-wo u-shukel-a a-ye-n-o-shukela w-anezel-a
# Target: we now have monthold mice that are nondiabetic that used to be diabetic he added
# Predicted: now we have eggs for four months sugar who were added
#
# Example 2:
# Source: u-dkt e-hud u-r u-solwazi w-e-zo-kw-elaph-a e-nyuvesi y-a-se-dalhos-ile e-halifax-e e-n-o-va scoti ka-nye n-o-si-hlalo wo-m-nyango w-e-zo-kw-elaph-a n-o-wesayensi we-canadina dibabes-e a-s-s-o-cititono u-xwayis-e ng-o-ku-thi u-cwaningo lu-s-and-a ku-qala
# Target: dr ehud ur professor of medicine at dalhousie university in halifax nova scotia and chair of the clinical and scientific division of the canadian diabetes association cautioned that the research is still in its early days
# Predicted: dr
#
# Example 3:
# Source: njengezinye i-z-azi u-n-o-ku-ngabaz-a uku-thi i-si-fo sika-shukela si-nga-lashw-a e-phawul-a uku-thi lo-khu oku-tholakel-e a-ku-ba-thint-i a-se-be-vel-e be-n-e-si-fo sika-shukela so-hlobo lo-ku
# Target: like some other experts he is skeptical about whether diabetes can be cured noting that these findings have no relevance to people who already have type  diabetes
# Predicted: as with other scholars you have doubts that diabetes can be treated to comment that this finding does not affect the already have diabetes of the sort
# Original pairs: 1012
# Valid pairs after filtering: 995
# Filtered out 17 pairs
# Original pairs: 1012
# Valid pairs after filtering: 995
# Filtered out 17 pairs
# Original pairs: 1012
# Valid pairs after filtering: 995
# Filtered out 17 pairs
# The evaluation results were successfully saved to:
# - Text format: zulu_english_models/zulu_english_seg_one/evaluation_results.txt
# Model: zulu_english_seg_one
# BLEU=0.1057
# CHRF: 0.3555
# Attempting to load from: zulu_english_models/zulu_english_seg_two/model_config.json
# Using device: cuda
# Device name: NVIDIA RTX A6000
# Device memory: 47.535888671875 GB
# Original shape: (100000, 5)
# Final shape: (100000, 5)
# The config file has been saved on zulu_english_models/zulu_english_seg_two
# the dataset length: 100000
# Tokenizer path: zulu_english_models/zulu_english_seg_two/tokenizers/tokenizers_segmenter_two.json
# Loading existing tokenizer from zulu_english_models/zulu_english_seg_two/tokenizers/tokenizers_segmenter_two.json
# Vocabulary finalized for inference
# Tokenizer path: zulu_english_models/zulu_english_seg_two/tokenizers/tokenizers_english.json
# Loading existing tokenizer from zulu_english_models/zulu_english_seg_two/tokenizers/tokenizers_english.json
# Max length of source sentence: 275
# Max length of target sentence: 77
# Loaded best model from epoch 19
# Model configuration:
# - d_model: 512
# - num_layers: 3
# - num_heads: 4
# - d_ff: 1024
# - dropout: 0.1203181097161564
# - label_smoothing: 0.042189608358574354
# - max_grad_norm: 0.638570395833354
# - lr: 0.00014227576020560835
# Reading predictions from: zulu_english_models/zulu_english_seg_two/external_predictions/test_predictions_20250113_033142.csv
# Successfully loaded 1012 predictions
#
# Example predictions:
#
# Example 1:
# Source: ma-nje si-na-ma-gundane a-ne-zinyanga e-zin-gu a-nge-na-wo u-shukel-a aye-no-shukela w-anezel-a
# Target: we now have monthold mice that are nondiabetic that used to be diabetic he added
# Predicted: now we have a month to have about sugar seven months which were diabetes added
#
# Example 2:
# Source: u-dkt e-hud u-r u-solw-azi we-zokw-elaph-a enyuves-i ya-s-e-dalhos-ise e-halif-a e-nov-a scot-a ka-nye no-si-hlalo wo-m-nyango we-zokw-elaph-a no-wesayensi we-canadina diabetes a-so-citatino u-xwayis-e ngo-ku-thi u-cwaningo lu-s-and-a ku-qal-a
# Target: dr ehud ur professor of medicine at dalhousie university in halifax nova scotia and chair of the clinical and scientific division of the canadian diabetes association cautioned that the research is still in its early days
# Predicted: dr
#
# Example 3:
# Source: njengeziny-e i-z-azi u-no-ku-ngabaz-a uku-thi isi-fo sika-shukela si-nga-lashw-a e-phawul-a uku-thi lo-khu oku-tholakel-e a-ku-ba-thint-i a-sebevel-e be-ne-si-fo sika-shukela so-hlobo lo-ku
# Target: like some other experts he is skeptical about whether diabetes can be cured noting that these findings have no relevance to people who already have type  diabetes
# Predicted: as other words you can have doubt that diabetes can be treated that comment that doesnt affect the ones already have diabetes type of diabetes
# Original pairs: 1012
# Valid pairs after filtering: 985
# Filtered out 27 pairs
# Original pairs: 1012
# Valid pairs after filtering: 985
# Filtered out 27 pairs
# Original pairs: 1012
# Valid pairs after filtering: 985
# Filtered out 27 pairs
# The evaluation results were successfully saved to:
# - Text format: zulu_english_models/zulu_english_seg_two/evaluation_results.txt
# Model: zulu_english_seg_two
# BLEU=0.1020
# CHRF: 0.3533
# Attempting to load from: zulu_english_models/zulu_english_seg_three/model_config.json
# Using device: cuda
# Device name: NVIDIA RTX A6000
# Device memory: 47.535888671875 GB
# Original shape: (100000, 5)
# Final shape: (100000, 5)
# The config file has been saved on zulu_english_models/zulu_english_seg_three/
# the dataset length: 100000
# Tokenizer path: zulu_english_models/zulu_english_seg_three/tokenizers/tokenizers_segmenter_three.json
# Loading existing tokenizer from zulu_english_models/zulu_english_seg_three/tokenizers/tokenizers_segmenter_three.json
# Vocabulary finalized for inference
# Tokenizer path: zulu_english_models/zulu_english_seg_three/tokenizers/tokenizers_english.json
# Loading existing tokenizer from zulu_english_models/zulu_english_seg_three/tokenizers/tokenizers_english.json
# Max length of source sentence: 219
# Max length of target sentence: 77
# Loaded best model from epoch 16
# Model configuration:
# - d_model: 512
# - num_layers: 4
# - num_heads: 4
# - d_ff: 2048
# - dropout: 0.13811200301393503
# - label_smoothing: 0.03567329797838283
# - max_grad_norm: 1.8165965265376862
# - lr: 6.524722484590323e-05
# Reading predictions from: zulu_english_models/zulu_english_seg_three/external_predictions/test_predictions_20250113_030859.csv
# Successfully loaded 1012 predictions
#
# Example predictions:
#
# Example 1:
# Source: manje sina-magundane ane-zinyanga e-zingu angena-wo u-shukel-a ayeno-shukela wanezel-a
# Target: we now have monthold mice that are nondiabetic that used to be diabetic he added
# Predicted: now we have a month of sugar insurance and had added
#
# Example 2:
# Source: udkt e-hud ur usolwazi w-ezokw-elaph-a e-nyuvesi ya-s-e-dalhosis-e e-halifaxa eno-va scoti k-any-e no-sihlalo wo-mnyango w-ezokw-elaph-a no-wesayensi we-canadina diabetes ass-ociation u-xwayis-e ngo-ku-thi ucwaningo lu-sand-a ku-qala
# Target: dr ehud ur professor of medicine at dalhousie university in halifax nova scotia and chair of the clinical and scientific division of the canadian diabetes association cautioned that the research is still in its early days
# Predicted: dr east medical universities in the early s in his family and the seat of the medical and the director of the assembly has warned that research was just the first research
#
# Example 3:
# Source: njengezinye izazi uno-ku-ngabaz-a uku-thi isifo sika-shukela singalashw-a ephawul-a uku-thi lo-khu okutholakel-e aku-ba-thint-i asebevel-e bene-sifo sika-shukela so-hlobo lo-ku
# Target: like some other experts he is skeptical about whether diabetes can be cured noting that these findings have no relevance to people who already have type  diabetes
# Predicted: as other scholars have a doubt that diabetes is advised that this failed not affect them who have already been diabetes on the type of diabetes
# Original pairs: 1012
# Valid pairs after filtering: 1012
# Filtered out 0 pairs
# Original pairs: 1012
# Valid pairs after filtering: 1012
# Filtered out 0 pairs
# Original pairs: 1012
# Valid pairs after filtering: 1012
# Filtered out 0 pairs
# The evaluation results were successfully saved to:
# - Text format: zulu_english_models/zulu_english_seg_three/evaluation_results.txt
# Model:
# BLEU=0.0888
# CHRF: 0.3537
#
# Comparison results saved to: model_comparison_results_zu_en_flores_testing_set.csv
#
# Comparison Summary:
#              model_name  bleu_score      chrf            timestamp
# 0     zulu_english_none    0.076161  0.328865  2025-03-24 23:33:08
# 1  zulu_english_seg_one    0.105688  0.355462  2025-03-24 23:33:16
# 2  zulu_english_seg_two    0.101979  0.353350  2025-03-24 23:33:25
# 3                          0.088848  0.353727  2025-03-24 23:33:33
